# %% [markdown]
# # Emissions Analysis
#
# This short notebook contains code to analyze the output of `codecarbon`'s `EmissionsTracker`.

# %%
import pandas as pd

# %%
# Load the CSV file for the Author Reconciliation Model
data = pd.read_csv('../logs/whisper-prepare-data-emissions-cpu.csv')

# Print the keys and values for each column in each row:
for row in data.itertuples(index=False):
    for column in data.columns:
        print(f"{column}: {getattr(row, column)}")
    print()  # Add a newline for better readability
# Out:
# timestamp: 2025-07-06T19:23:49
# project_name: whisper-enenlhet-cpu
# run_id: 8ba44c59-85c2-4172-8893-71362914d023
# duration: 4.230378150939941
# emissions: 2.8647410834874897e-05
# emissions_rate: 6.77183216552633e-06
# cpu_power: 42.5
# gpu_power: 0.0
# ram_power: 9.000000000000002
# cpu_energy: 4.9937429858578576e-05
# gpu_energy: 0
# ram_energy: 1.0573983192443849e-05
# energy_consumed: 6.0511413051022426e-05
# country_name: United States
# country_iso_code: USA
# region: oklahoma
# cloud_provider: nan
# cloud_region: nan
# os: macOS-15.5-arm64-arm-64bit
# python_version: 3.10.9
# codecarbon_version: 2.2.2
# cpu_count: 12
# cpu_model: Apple M4 Pro
# gpu_count: nan
# gpu_model: nan
# longitude: -97.4095
# latitude: 35.2338
# ram_total_size: 24.0
# tracking_mode: machine
# on_cloud: N
#
# timestamp: 2025-07-06T19:25:41
# project_name: whisper-enenlhet-cpu
# run_id: 95f273cd-d89c-4067-aeef-54387c99fb98
# duration: 3.8108861446380615
# emissions: 2.580615808930369e-05
# emissions_rate: 6.771694852551053e-06
# cpu_power: 42.5
# gpu_power: 0.0
# ram_power: 9.000000000000002
# cpu_energy: 4.4984775616063015e-05
# gpu_energy: 0
# ram_energy: 9.525110125541688e-06
# energy_consumed: 5.4509885741604705e-05
# country_name: United States
# country_iso_code: USA
# region: oklahoma
# cloud_provider: nan
# cloud_region: nan
# os: macOS-15.5-arm64-arm-64bit
# python_version: 3.10.9
# codecarbon_version: 2.2.2
# cpu_count: 12
# cpu_model: Apple M4 Pro
# gpu_count: nan
# gpu_model: nan
# longitude: -97.4095
# latitude: 35.2338
# ram_total_size: 24.0
# tracking_mode: machine
# on_cloud: N
#
# timestamp: 2025-07-08T14:43:20
# project_name: whisper-enenlhet-cpu
# run_id: c128f545-caae-486a-9303-d67f31c9e67c
# duration: 17456.214709043503
# emissions: 0.1181797832395729
# emissions_rate: 6.770069296773017e-06
# cpu_power: 42.5
# gpu_power: 0.0
# ram_power: 9.000000000000002
# cpu_energy: 0.2060419182209503
# gpu_energy: 0
# ram_energy: 0.0435871222221851
# energy_consumed: 0.2496290404431352
# country_name: United States
# country_iso_code: USA
# region: oklahoma
# cloud_provider: nan
# cloud_region: nan
# os: macOS-15.5-arm64-arm-64bit
# python_version: 3.10.9
# codecarbon_version: 2.2.2
# cpu_count: 12
# cpu_model: Apple M4 Pro
# gpu_count: nan
# gpu_model: nan
# longitude: -97.4095
# latitude: 35.2338
# ram_total_size: 24.0
# tracking_mode: machine
# on_cloud: N

# %%
# Load the CSV file for the Greek-Latin Identification Model
data = pd.read_csv('../logs/greek_latin_emissions_log.csv')

# Print each column title followed by its value, formatted vertically
for column in data.columns:
    print(f"{column}: {data.iloc[0][column]}")
# Out:
# timestamp: 2025-06-12T17:07:28
# project_name: codecarbon
# run_id: e9ec6b22-3102-4fb8-80bb-cf1a15740b8b
# duration: 1348.9958429336548
# emissions: 0.0091357690759099
# emissions_rate: 6.772273705486325e-06
# cpu_power: 42.5
# gpu_power: 0.0
# ram_power: 9.000000000000002
# cpu_energy: 0.0159251248127884
# gpu_energy: 0
# ram_energy: 0.0033721966546773
# energy_consumed: 0.0192973214674658
# country_name: United States
# country_iso_code: USA
# region: oklahoma
# cloud_provider: nan
# cloud_region: nan
# os: macOS-15.5-arm64-arm-64bit
# python_version: 3.10.9
# codecarbon_version: 2.2.2
# cpu_count: 12
# cpu_model: Apple M4 Pro
# gpu_count: nan
# gpu_model: nan
# longitude: -97.4536
# latitude: 35.2144
# ram_total_size: 24.0
# tracking_mode: machine
# on_cloud: N
