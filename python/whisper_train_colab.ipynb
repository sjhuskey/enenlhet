# %% [markdown]
# # Fine-tune Whisper for Enenlhet on Google Colab
#
# It should be noted at the outset that Enenlhet is a low-resource, endangered language, so it doesn't have any pre-built tokenizers or any other items that Whisper models require.
#
# I'm going to try here to make a notebook that will successfully fine-tune a Whisper model. To do that, I need to:
#
# 1. Set up the environment properly
#     a. Install packages
#     b. Make sure we're using the GPU
#     c. Create directories
# 2. Prepare the dataset
# 3. Download configure the model
# 4. Write a custom data collator
# 5. Set up a `compute_metrics` function to use Word Error Rate to measure the model's performance
# 6. Set up and initialize a trainer with arguments optimized for GPU
# 7. Train the model
# 8. Save the output
# 9. Evaluate the model

# %% [markdown]
# ## Set up the environment
#
# ### Install packages
#
# Several packages are not installed by default on Google Colab, so they must be added.

# %%
# Install necessary packages
# !pip install transformers datasets accelerate evaluate huggingface_hub codecarbon jiwer --quiet
# If you don't update datasets and fsspec, there will be errors when you load the dataset.
# !pip install -U datasets fsspec --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.7/277.7 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 112.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 9.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.31.0 requires httpx<1.0.0,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# firebase-admin 6.9.0 requires httpx[http2]==0.28.1, but you have httpx 0.27.2 which is incompatible.

# %% [markdown]
# ### Import the necessary libraries
#
# Most of the libraries I'll use are from the Hugging Face API:
#
# - `datasets`: for importing and providing datasets to the model
# - `evaluate`: standardizes the way evaluation metrics are implemented
# - `transformers`: contains the Whisper libraries
#
# I will also make use of the following individual Python libraries
#
# - `dataclasses`: for defining the data collator as a class
# - `numpy`: for handling some of the mathematical operations
# - `os`: for interacting with the operating system
# - `random`: for generating a random seed (if I decide to do that)
# - `torch`: standard library for machine learning functionality
# - `typing`: necessary for the data collator
# - `tqdm`: for showing a progress meter

# %%
# Import necessary libraries
#from codecarbon import EmissionsTracker

# Hugging Face API
from datasets import (
    Audio,
    Dataset,
    DatasetDict,
    load_dataset
)
import evaluate
from transformers import (
    WhisperProcessor,
    WhisperForConditionalGeneration,
    WhisperFeatureExtractor,
    WhisperTokenizer
)
from transformers.trainer_callback import EarlyStoppingCallback
from transformers.trainer_seq2seq import Seq2SeqTrainer
from transformers.training_args_seq2seq import Seq2SeqTrainingArguments

# Python Libraries
from codecarbon import EmissionsTracker
from dataclasses import dataclass
import numpy as np
import os
import random
import torch
from typing import Any, Dict, List, Union
import tqdm

# %%
from google.colab import userdata
hf_token = userdata.get('SJHColab')

# %% [markdown]
# ### Make sure that we're using a GPU

# %%
# Check if GPU is available
if not torch.cuda.is_available():
    raise RuntimeError("GPU is not available. Please enable GPU in 'Runtime > Change runtime type'.")
else:
    print("GPU is available:", torch.cuda.get_device_name(0))
# Out:
# GPU is available: NVIDIA A100-SXM4-40GB

# %% [markdown]
# ### Create directories

# %%
# Create necessary directories
output_dir = "./enenlhet-whisper-model"
log_dir = "./logs"
dataset_dir = "./enenlhet-dataset"

# If directories do not exist, create them
os.makedirs(output_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)
os.makedirs(dataset_dir, exist_ok=True)

# %% [markdown]
# ### Download the dataset

# %%
dataset = load_dataset("sjhuskey/enenlhet-whisper-dataset")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00006.parquet:   0%|          | 0.00/69.1M [00:00<?, ?B/s]
# data/train-00001-of-00006.parquet:   0%|          | 0.00/69.6M [00:00<?, ?B/s]
# data/train-00002-of-00006.parquet:   0%|          | 0.00/69.5M [00:00<?, ?B/s]
# data/train-00003-of-00006.parquet:   0%|          | 0.00/69.2M [00:00<?, ?B/s]
# data/train-00004-of-00006.parquet:   0%|          | 0.00/68.2M [00:00<?, ?B/s]
# data/train-00005-of-00006.parquet:   0%|          | 0.00/69.4M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/23.2M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/23.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3053 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/170 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/170 [00:00<?, ? examples/s]

# %% [markdown]
# ## Set up the model
#
# This needs some explanation, since I have had to implement a lot of custom configurations just to get Whisper to train. Indeed, this step was so difficult to get right that I resorted to three different LLM's to deal with all the errors that arose. Ultimately, Claude Sonnet 4 was able to provide a clean function that would configure the model correctly.
#
# The `setup_whisper_model()` function attempts to set some options of the `whisper-small` model and alter others. First, it loads the model and the model's processor. Second, it sets the language, which I've set to Spanish for now, since Enenlhet is not an option, and Whisper demands that a language be set. If I leave the selection to Whisper's auto-detection, I'll end up with a lot of poor attempts to force the inputs into a language. Third, the function sets the `pad_token` and the `eos_token` (eos = end-of-sentence) to values different from each other. Fourth, the function adjusts the configuration for the model's generation side. Fifth, the function cleans up some deprecated settings. Finally, the function moves the model to the GPU (if one is available) and verifies the settings.
#
# When I call the function, I set the `model_name`, `target_language`, and `max_length`. I figured out the max_length for my dataset by doing this:
#
# ```
# label_lengths = []
# for sample in dataset["train"]:
#     if 'labels' in sample:
#         label_lengths.append(len(sample['labels']))
#
# # Calculate statistics
# lengths = np.array(label_lengths)
# print(f"Min length: {lengths.min()}")
# print(f"Max length: {lengths.max()}")
# print(f"Mean length: {lengths.mean():.1f}")
# print(f"Median length: {np.median(lengths):.1f}")
# print(f"95th percentile: {np.percentile(lengths, 95):.1f}")
# print(f"99th percentile: {np.percentile(lengths, 99):.1f}")
# ```

# %%
# Clean Whisper Model Loading and Configuration
def setup_whisper_model(model_name="openai/whisper-small", target_language="es", max_length=60):
    """
    Load and configure Whisper model for fine-tuning.

    Args:
        model_name: Hugging Face model identifier
        target_language: Language code (e.g., "es" for Spanish)
        max_length: Maximum generation length based on your data analysis

    Returns:
        model, processor: Configured model and processor
    """
    print(f"Loading model: {model_name}")

    # 1. Load model and processor
    # Set language and task directly during processor initialization
    processor = WhisperProcessor.from_pretrained(model_name, language=target_language, task="transcribe")
    model = WhisperForConditionalGeneration.from_pretrained(model_name)


    # 2. Set language and task (if you want to fix to Spanish transcription)
    # This step is no longer needed as language and task are set in processor initialization
    # if target_language:
    #     processor.tokenizer.set_prefix_tokens([f"<|{target_language}|>", "<|transcribe|>"])
    #     print(f"Set language to: {target_language}")
    # else:
    #     print("Using auto-detection for language")


    # 3. Fix pad token issue (pad token != eos token)
    original_pad = processor.tokenizer.pad_token_id
    original_eos = processor.tokenizer.eos_token_id

    processor.tokenizer.pad_token = processor.tokenizer.unk_token
    model.config.pad_token_id = processor.tokenizer.pad_token_id

    print(f"Pad token changed: {original_pad} -> {processor.tokenizer.pad_token_id}")
    print(f"EOS token: {original_eos}")
    print(f"Pad != EOS: {processor.tokenizer.pad_token_id != processor.tokenizer.eos_token_id}")

    # 4. Configure generation settings
    model.generation_config.max_length = max_length
    model.generation_config.pad_token_id = processor.tokenizer.pad_token_id
    model.generation_config.eos_token_id = processor.tokenizer.eos_token_id
    model.generation_config.forced_decoder_ids = None
    model.generation_config.suppress_tokens = []
    model.generation_config.begin_suppress_tokens = []
    model.generation_config.do_sample = False
    model.generation_config.num_beams = 1

    # Set language and task in generation config as well
    model.generation_config.language = target_language
    model.generation_config.task = "transcribe"


    # 5. Clean up deprecated config attributes
    deprecated_attrs = ['max_length', 'suppress_tokens', 'begin_suppress_tokens', 'forced_decoder_ids']
    for attr in deprecated_attrs:
        if hasattr(model.config, attr):
            delattr(model.config, attr)
            print(f"Removed deprecated config.{attr}")

    # 6. Move to GPU if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    print(f"Model moved to: {device}")

    # 7. Verify configuration
    print("\n=== Configuration Summary ===")
    print(f"Max generation length: {model.generation_config.max_length}")
    print(f"Language: {model.generation_config.language or 'auto-detect'}")
    print(f"Task: {model.generation_config.task}")
    print(f"Pad token ID: {processor.tokenizer.pad_token_id}")
    print(f"EOS token ID: {processor.tokenizer.eos_token_id}")
    print(f"Has Whisper task_to_id: {hasattr(model.generation_config, 'task_to_id')}")
    print("Configuration complete!")

    return model, processor

# Usage
model, processor = setup_whisper_model(
    model_name="openai/whisper-small",
    target_language="es",
    max_length=60
)
# Out:
# Loading model: openai/whisper-small
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# normalizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json: 0.00B [00:00, ?B/s]
# Pad token changed: 50257 -> 50257
# EOS token: 50257
# Pad != EOS: False
# Removed deprecated config.max_length
# Removed deprecated config.suppress_tokens
# Removed deprecated config.begin_suppress_tokens
# Removed deprecated config.forced_decoder_ids
# Model moved to: cuda
#
# === Configuration Summary ===
# Max generation length: 60
# Language: es
# Task: transcribe
# Pad token ID: 50257
# EOS token ID: 50257
# Has Whisper task_to_id: True
# Configuration complete!

# %% [markdown]
# ### Create the data collator
#
# A data collator takes elements from the prepared datasets and creates batches for passing to the model. It also applies extra processing steps, like padding and masking here, to ensure that all the inputs are the same length.
#
# Note that `input_features` and `label_features` correspond to "audio" and text, respectively, in the original dataset.
#
# Note, too, that `-100` is a special value that PyTorch loss functions will ignore. The data collator replaces the padding token with `-100` so that the padding will be ignored. Otherwise, the model would try to interpret the padding token, which is meaningless.

# %%
# Define the custom DataCollator class

@dataclass
class DataCollatorForWhisper:
    processor: Any
    padding: Union[bool, str] = "longest"

    def __call__(self, features: List[Dict[str, Any]]) -> Dict[str, Any]:
        # Separate inputs and labels
        input_features = [{"input_features": f["input_features"]} for f in features]
        label_features = [{"input_ids": f["labels"]} for f in features]

        # Collate audio features
        batch = self.processor.feature_extractor.pad(
          input_features,
          padding=self.padding,
          return_tensors="pt"
        )

        # Collate labels (token IDs)
        labels_batch = self.processor.tokenizer.pad(
            label_features,
            padding=self.padding,
            return_tensors="pt"
        )

        # Replace padding token ID by -100 to ignore in loss
        labels = labels_batch["input_ids"].masked_fill(
            labels_batch["input_ids"] == self.processor.tokenizer.pad_token_id, -100
        )

        batch["labels"] = labels
        return batch


# Initialize the data collator
data_collator = DataCollatorForWhisper(processor=processor, padding="longest")

# %% [markdown]
# ### Define a custom `compute_metrics() function
#
# The best metric for an ASR model is Word Error Rate (WER), so the `compute_metrics()` function must focus on that.

# %%
# Evaluation metric
wer_metric = evaluate.load("wer")

def compute_metrics(pred):
    # Unpack logits from tuple
    if isinstance(pred.predictions, tuple):
        logits = pred.predictions[0]
    else:
        logits = pred.predictions

    pred_ids = torch.argmax(torch.tensor(logits), dim=-1)

    # Decode predictions
    pred_str = processor.tokenizer.batch_decode(pred_ids, skip_special_tokens=True)

    # Handle labels
    label_ids = pred.label_ids
    label_ids = [
        [token if token != -100 else processor.tokenizer.pad_token_id for token in label]
        for label in label_ids
    ]
    label_str = processor.tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    return {"wer": wer_metric.compute(predictions=pred_str, references=label_str)}
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]

# %% [markdown]
# ### Define the model's settings
#
# The `training_args` variable holds many important settings that affect the outcome of the fine-tuning. The settings here are optimized for use when fine-tuning on a GPU.
#
# I'm going to explain the settings, even though they are [documented on Hugging Face](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.TrainingArguments), since I want to be sure that I understand them. 🤓
#
# - `run_name`: This is just a way to keep track of the training runs.
# - `output_dir`: This is where the model's files will be stored. The output directory was defined earlier in this notebook.
# - `per_device_train_batch_size`: The number of input and label pairs included per batch sent to the device (GPU) for training.
# - `gradient_accumulation_steps`: The trainer will perform a backward pass after two steps. The backward pass is part of the learning process, where the model makes adjustments based on what it has learned to that point. This setting is inversely proportional to `per_device_train_batch_size`: increase by 2x for every 2x decrease in batch size.
# - `per_device_eval_batch_size`: The number of input and label pairs included per batch sent to the device (GPU) for evaluation.
# - `learning_rate`: This is the, well, learning rate for the optimizer. I have selected `1.25e-5` (i.e., 1.25 x 10 − 5) as suggested at <https://github.com/vasistalodagala/whisper-finetune>
# - `predict_with_generate`: This is set to `True` because the model generates predictions for transcriptions.
# - `warmup_steps`: The warmup process helps to avoid any overfitting in the early stages of training, before the model has had a chance to learn.
# - `fp16`: This is a performance boost. It tells the trainer to use 16-bit floating point numbers instead of the default 32-bit, which take longer to calculate.
# - `eval_strategy`: The evaluation (WER) will be performed after each epoch.
# - `num_train_epochs`: I have set the total number of epochs to 30 so that the model has a chance to learn. The early stopping callback (see below) will probably make sure that it never reaches that limit.
# - `save_strategy`: Set to the same as `eval_strategy`.
# - `save_total_limit`: I'm setting this to be the same as `num_train_epochs` so that `load_best_model_at_end` will have the full range of checkpoints from which to select.
# - `logging_dir`: This is where the logs will be saved. I set it earlier in the notebook.
# - `logging_steps`: How often information will be logged
# - `report_to`: This will send the log data to Tensorboard, which is a nice way of visualizing the information.
# - `load_best_model_at_end`: This ensures that only the best model is loaded for saving.
# - `metric_for_best_model`: Defines Word Error Rate as the metric for determining the best model.
# - `greater_is_better`: This is set to false because a lower WER is better.
# - `hub_model_id`: Identifies the model repo on Hugging Face Hub.
# - ` hub_strategy`: Set to `end` to push to the hub when the trainer has finished.
# - `push_to_hub`: Pushes the model to the hub at the end of the training.
#
# I have used epochs instead of steps to allow the Hugging Face API calculate the number of steps per epoch.

# %%
training_args = Seq2SeqTrainingArguments(
    run_name="enenlhet-whisper-model",
    output_dir=output_dir,
    per_device_train_batch_size=16,
    gradient_accumulation_steps=2,
    learning_rate=1.25e-5,
    predict_with_generate=False,
    generation_max_length=80,
    warmup_steps=500,
    fp16=True,
    eval_strategy="epoch",
    num_train_epochs=15,
    save_strategy="epoch",
    save_total_limit=15,
    logging_dir=log_dir,
    logging_steps=10,
    report_to="tensorboard",
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    # hub_model_id="sjhuskey/enenlhet-whisper-model",
    # hub_strategy="end",
    # push_to_hub=False,
    # hub_token=hf_token
)

# %% [markdown]
# ### Initialize the trainer
#
# The `trainer` gets some additional settings here, including the splits to use for training and testing. Note that most of the settings just point back to previously defined variables. The new part is the implementation of `EarlyStoppingCallback`, which monitors the WER and halts the training after n epochs without a certain amount of improvement.

# %%
# Initialize the trainer
trainer = Seq2SeqTrainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    processing_class=processor.tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=3, early_stopping_threshold=0.1)]
)

# %%
# Set up CodeCarbon's EmissionsTracker
tracker = EmissionsTracker(
    output_dir="./logs",
    output_file="enenlhet_whisper_emissions_log.csv"
)
tracker.start()
# Out:
# [codecarbon WARNING @ 21:18:14] Multiple instances of codecarbon are allowed to run at the same time.
# [codecarbon INFO @ 21:18:14] [setup] RAM Tracking...
# [codecarbon INFO @ 21:18:14] [setup] CPU Tracking...
# [codecarbon WARNING @ 21:18:16] We saw that you have a Intel(R) Xeon(R) CPU @ 2.20GHz but we don't know it. Please contact us.
# [codecarbon WARNING @ 21:18:16] No CPU tracking mode found. Falling back on estimation based on TDP for CPU.
#  Linux OS detected: Please ensure RAPL files exist at /sys/class/powercap/intel-rapl/subsystem to measure CPU
#
# [codecarbon INFO @ 21:18:16] CPU Model on constant consumption mode: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon WARNING @ 21:18:16] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 21:18:16] [setup] GPU Tracking...
# [codecarbon INFO @ 21:18:16] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 21:18:16] The below tracking methods have been set up:
#                 RAM Tracking Method: RAM power estimation model
#                 CPU Tracking Method: global constant
#                 GPU Tracking Method: pynvml
#
# [codecarbon INFO @ 21:18:16] >>> Tracker's metadata:
# [codecarbon INFO @ 21:18:16]   Platform system: Linux-6.1.123+-x86_64-with-glibc2.35
# [codecarbon INFO @ 21:18:16]   Python version: 3.12.11
# [codecarbon INFO @ 21:18:16]   CodeCarbon version: 3.0.4
# [codecarbon INFO @ 21:18:16]   Available RAM : 83.476 GB
# [codecarbon INFO @ 21:18:16]   CPU count: 12 thread(s) in 1 physical CPU(s)
# [codecarbon INFO @ 21:18:16]   CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz
# [codecarbon INFO @ 21:18:16]   GPU count: 1
# [codecarbon INFO @ 21:18:16]   GPU model: 1 x NVIDIA A100-SXM4-40GB
# [codecarbon INFO @ 21:18:16] Emissions data (if any) will be saved to file /content/logs/enenlhet_whisper_emissions_log.csv

# %% [markdown]
# ## Train the model

# %%
train_result = trainer.train()
# Out:
# You're using a WhisperTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='768' max='1440' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 768/1440 55:24 < 48:36, 0.23 it/s, Epoch 8/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.994700</td>
#       <td>3.676985</td>
#       <td>1.591700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.001900</td>
#       <td>1.887706</td>
#       <td>1.597055</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.541100</td>
#       <td>1.465359</td>
#       <td>1.804552</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.967300</td>
#       <td>1.218838</td>
#       <td>1.504685</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.529700</td>
#       <td>0.959480</td>
#       <td>1.105756</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.281000</td>
#       <td>0.960863</td>
#       <td>1.733601</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.122700</td>
#       <td>0.968978</td>
#       <td>1.437751</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.065600</td>
#       <td>0.992428</td>
#       <td>1.341365</td>
#     </tr>
#   </tbody>
# </table><p>
# [codecarbon INFO @ 21:18:32] Energy consumed for RAM : 0.000168 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:18:32] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:18:32] Energy consumed for All CPU : 0.000189 kWh
# [codecarbon INFO @ 21:18:32] Energy consumed for all GPUs : 0.000293 kWh. Total GPU Power : 65.56256621117141 W
# [codecarbon INFO @ 21:18:32] 0.000650 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:18:47] Energy consumed for RAM : 0.000324 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:18:47] Delta energy consumed for CPU with constant : 0.000175 kWh, power : 42.5 W
# [codecarbon INFO @ 21:18:47] Energy consumed for All CPU : 0.000364 kWh
# [codecarbon INFO @ 21:18:47] Energy consumed for all GPUs : 0.000645 kWh. Total GPU Power : 85.03012853352713 W
# [codecarbon INFO @ 21:18:47] 0.001333 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:19:02] Energy consumed for RAM : 0.000480 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:19:02] Delta energy consumed for CPU with constant : 0.000175 kWh, power : 42.5 W
# [codecarbon INFO @ 21:19:02] Energy consumed for All CPU : 0.000539 kWh
# [codecarbon INFO @ 21:19:02] Energy consumed for all GPUs : 0.000982 kWh. Total GPU Power : 81.7536088817343 W
# [codecarbon INFO @ 21:19:02] 0.002002 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:19:18] Energy consumed for RAM : 0.000647 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:19:18] Delta energy consumed for CPU with constant : 0.000187 kWh, power : 42.5 W
# [codecarbon INFO @ 21:19:18] Energy consumed for All CPU : 0.000727 kWh
# [codecarbon INFO @ 21:19:18] Energy consumed for all GPUs : 0.001329 kWh. Total GPU Power : 78.30572324733954 W
# [codecarbon INFO @ 21:19:18] 0.002702 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:19:33] Energy consumed for RAM : 0.000803 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:19:33] Delta energy consumed for CPU with constant : 0.000175 kWh, power : 42.5 W
# [codecarbon INFO @ 21:19:33] Energy consumed for All CPU : 0.000901 kWh
# [codecarbon INFO @ 21:19:34] Energy consumed for all GPUs : 0.001686 kWh. Total GPU Power : 86.73106616117155 W
# [codecarbon INFO @ 21:19:34] 0.003389 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:19:49] Energy consumed for RAM : 0.000958 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:19:49] Delta energy consumed for CPU with constant : 0.000175 kWh, power : 42.5 W
# [codecarbon INFO @ 21:19:49] Energy consumed for All CPU : 0.001076 kWh
# [codecarbon INFO @ 21:19:49] Energy consumed for all GPUs : 0.002059 kWh. Total GPU Power : 89.7813030156032 W
# [codecarbon INFO @ 21:19:49] 0.004094 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:20:04] Energy consumed for RAM : 0.001114 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:20:04] Delta energy consumed for CPU with constant : 0.000174 kWh, power : 42.5 W
# [codecarbon INFO @ 21:20:04] Energy consumed for All CPU : 0.001250 kWh
# [codecarbon INFO @ 21:20:06] Energy consumed for all GPUs : 0.002431 kWh. Total GPU Power : 81.9421019371135 W
# [codecarbon INFO @ 21:20:06] 0.004795 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:20:20] Energy consumed for RAM : 0.001266 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:20:20] Delta energy consumed for CPU with constant : 0.000170 kWh, power : 42.5 W
# [codecarbon INFO @ 21:20:20] Energy consumed for All CPU : 0.001421 kWh
# [codecarbon INFO @ 21:20:20] Energy consumed for all GPUs : 0.002741 kWh. Total GPU Power : 76.71134324800764 W
# [codecarbon INFO @ 21:20:20] 0.005427 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:20:20] 0.020551 g.CO2eq/s mean an estimation of 648.0864706183587 kg.CO2eq/year
# [codecarbon INFO @ 21:20:36] Energy consumed for RAM : 0.001435 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:20:36] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:20:36] Energy consumed for All CPU : 0.001611 kWh
# [codecarbon INFO @ 21:20:36] Energy consumed for all GPUs : 0.003117 kWh. Total GPU Power : 83.52705184107475 W
# [codecarbon INFO @ 21:20:36] 0.006164 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:20:51] Energy consumed for RAM : 0.001592 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:20:51] Delta energy consumed for CPU with constant : 0.000175 kWh, power : 42.5 W
# [codecarbon INFO @ 21:20:51] Energy consumed for All CPU : 0.001787 kWh
# [codecarbon INFO @ 21:20:51] Energy consumed for all GPUs : 0.003467 kWh. Total GPU Power : 84.60719106378659 W
# [codecarbon INFO @ 21:20:51] 0.006845 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:21:08] Energy consumed for RAM : 0.001765 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:21:08] Delta energy consumed for CPU with constant : 0.000194 kWh, power : 42.5 W
# [codecarbon INFO @ 21:21:08] Energy consumed for All CPU : 0.001980 kWh
# [codecarbon INFO @ 21:21:08] Energy consumed for all GPUs : 0.003844 kWh. Total GPU Power : 82.22462790233445 W
# [codecarbon INFO @ 21:21:08] 0.007589 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:21:24] Energy consumed for RAM : 0.001935 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:21:24] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 21:21:24] Energy consumed for All CPU : 0.002172 kWh
# [codecarbon INFO @ 21:21:24] Energy consumed for all GPUs : 0.004221 kWh. Total GPU Power : 82.83402078819907 W
# [codecarbon INFO @ 21:21:24] 0.008327 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:21:39] Energy consumed for RAM : 0.002091 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:21:39] Delta energy consumed for CPU with constant : 0.000174 kWh, power : 42.5 W
# [codecarbon INFO @ 21:21:39] Energy consumed for All CPU : 0.002346 kWh
# [codecarbon INFO @ 21:21:39] Energy consumed for all GPUs : 0.004538 kWh. Total GPU Power : 77.35427039748129 W
# [codecarbon INFO @ 21:21:39] 0.008975 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:21:55] Energy consumed for RAM : 0.002261 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:21:55] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 21:21:55] Energy consumed for All CPU : 0.002537 kWh
# [codecarbon INFO @ 21:21:55] Energy consumed for all GPUs : 0.004902 kWh. Total GPU Power : 80.60023204927033 W
# [codecarbon INFO @ 21:21:55] 0.009700 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:22:12] Energy consumed for RAM : 0.002434 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:22:12] Delta energy consumed for CPU with constant : 0.000193 kWh, power : 42.5 W
# [codecarbon INFO @ 21:22:12] Energy consumed for All CPU : 0.002730 kWh
# [codecarbon INFO @ 21:22:12] Energy consumed for all GPUs : 0.005279 kWh. Total GPU Power : 82.70921679286012 W
# [codecarbon INFO @ 21:22:12] 0.010443 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:22:27] Energy consumed for RAM : 0.002590 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:22:27] Delta energy consumed for CPU with constant : 0.000175 kWh, power : 42.5 W
# [codecarbon INFO @ 21:22:27] Energy consumed for All CPU : 0.002905 kWh
# [codecarbon INFO @ 21:22:27] Energy consumed for all GPUs : 0.005628 kWh. Total GPU Power : 84.88349464943322 W
# [codecarbon INFO @ 21:22:27] 0.011122 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:22:27] 0.021175 g.CO2eq/s mean an estimation of 667.7636880592098 kg.CO2eq/year
# [codecarbon INFO @ 21:22:43] Energy consumed for RAM : 0.002762 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:22:43] Delta energy consumed for CPU with constant : 0.000193 kWh, power : 42.5 W
# [codecarbon INFO @ 21:22:43] Energy consumed for All CPU : 0.003098 kWh
# [codecarbon INFO @ 21:22:43] Energy consumed for all GPUs : 0.005998 kWh. Total GPU Power : 81.12073558845542 W
# [codecarbon INFO @ 21:22:43] 0.011857 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:23:00] Energy consumed for RAM : 0.002934 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:23:00] Delta energy consumed for CPU with constant : 0.000193 kWh, power : 42.5 W
# [codecarbon INFO @ 21:23:00] Energy consumed for All CPU : 0.003291 kWh
# [codecarbon INFO @ 21:23:00] Energy consumed for all GPUs : 0.006372 kWh. Total GPU Power : 81.78173073107536 W
# [codecarbon INFO @ 21:23:00] 0.012597 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:23:16] Energy consumed for RAM : 0.003106 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:23:16] Delta energy consumed for CPU with constant : 0.000194 kWh, power : 42.5 W
# [codecarbon INFO @ 21:23:16] Energy consumed for All CPU : 0.003485 kWh
# [codecarbon INFO @ 21:23:16] Energy consumed for all GPUs : 0.006747 kWh. Total GPU Power : 81.60197056907664 W
# [codecarbon INFO @ 21:23:16] 0.013337 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:23:33] Energy consumed for RAM : 0.003277 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:23:33] Delta energy consumed for CPU with constant : 0.000193 kWh, power : 42.5 W
# [codecarbon INFO @ 21:23:33] Energy consumed for All CPU : 0.003677 kWh
# [codecarbon INFO @ 21:23:33] Energy consumed for all GPUs : 0.007123 kWh. Total GPU Power : 82.77492532439078 W
# [codecarbon INFO @ 21:23:33] 0.014078 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:23:48] Energy consumed for RAM : 0.003433 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:23:48] Delta energy consumed for CPU with constant : 0.000174 kWh, power : 42.5 W
# [codecarbon INFO @ 21:23:48] Energy consumed for All CPU : 0.003852 kWh
# [codecarbon INFO @ 21:23:48] Energy consumed for all GPUs : 0.007466 kWh. Total GPU Power : 83.55256995377614 W
# [codecarbon INFO @ 21:23:48] 0.014751 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:24:04] Energy consumed for RAM : 0.003600 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:24:04] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:24:04] Energy consumed for All CPU : 0.004040 kWh
# [codecarbon INFO @ 21:24:04] Energy consumed for all GPUs : 0.007808 kWh. Total GPU Power : 76.82370316737466 W
# [codecarbon INFO @ 21:24:04] 0.015448 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:24:19] Energy consumed for RAM : 0.003756 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:24:19] Delta energy consumed for CPU with constant : 0.000175 kWh, power : 42.5 W
# [codecarbon INFO @ 21:24:19] Energy consumed for All CPU : 0.004215 kWh
# [codecarbon INFO @ 21:24:19] Energy consumed for all GPUs : 0.008151 kWh. Total GPU Power : 83.00382107575587 W
# [codecarbon INFO @ 21:24:19] 0.016122 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:24:33] Energy consumed for RAM : 0.003913 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:24:33] Delta energy consumed for CPU with constant : 0.000176 kWh, power : 42.5 W
# [codecarbon INFO @ 21:24:33] Energy consumed for All CPU : 0.004391 kWh
# [codecarbon INFO @ 21:24:33] Energy consumed for all GPUs : 0.008475 kWh. Total GPU Power : 78.10813882594339 W
# [codecarbon INFO @ 21:24:33] 0.016779 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:24:33] 0.021031 g.CO2eq/s mean an estimation of 663.2429699679449 kg.CO2eq/year
# [codecarbon INFO @ 21:24:49] Energy consumed for RAM : 0.004081 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:24:49] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:24:50] Energy consumed for All CPU : 0.004580 kWh
# [codecarbon INFO @ 21:24:50] Energy consumed for all GPUs : 0.008833 kWh. Total GPU Power : 80.27656576252814 W
# [codecarbon INFO @ 21:24:50] 0.017494 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:25:05] Energy consumed for RAM : 0.004244 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:25:05] Delta energy consumed for CPU with constant : 0.000183 kWh, power : 42.5 W
# [codecarbon INFO @ 21:25:05] Energy consumed for All CPU : 0.004762 kWh
# [codecarbon INFO @ 21:25:05] Energy consumed for all GPUs : 0.009152 kWh. Total GPU Power : 74.21065093315029 W
# [codecarbon INFO @ 21:25:05] 0.018158 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:25:20] Energy consumed for RAM : 0.004401 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:25:20] Delta energy consumed for CPU with constant : 0.000176 kWh, power : 42.5 W
# [codecarbon INFO @ 21:25:20] Energy consumed for All CPU : 0.004939 kWh
# [codecarbon INFO @ 21:25:20] Energy consumed for all GPUs : 0.009383 kWh. Total GPU Power : 55.59193994480084 W
# [codecarbon INFO @ 21:25:20] 0.018722 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:25:36] Energy consumed for RAM : 0.004566 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:25:36] Delta energy consumed for CPU with constant : 0.000186 kWh, power : 42.5 W
# [codecarbon INFO @ 21:25:36] Energy consumed for All CPU : 0.005124 kWh
# [codecarbon INFO @ 21:25:36] Energy consumed for all GPUs : 0.009675 kWh. Total GPU Power : 66.53811457751044 W
# [codecarbon INFO @ 21:25:36] 0.019365 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:25:52] Energy consumed for RAM : 0.004736 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:25:52] Delta energy consumed for CPU with constant : 0.000192 kWh, power : 42.5 W
# [codecarbon INFO @ 21:25:52] Energy consumed for All CPU : 0.005317 kWh
# [codecarbon INFO @ 21:25:52] Energy consumed for all GPUs : 0.010045 kWh. Total GPU Power : 81.56336516427199 W
# [codecarbon INFO @ 21:25:52] 0.020098 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:26:08] Energy consumed for RAM : 0.004905 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:26:08] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:26:08] Energy consumed for All CPU : 0.005506 kWh
# [codecarbon INFO @ 21:26:08] Energy consumed for all GPUs : 0.010418 kWh. Total GPU Power : 83.30509431976272 W
# [codecarbon INFO @ 21:26:08] 0.020830 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:26:25] Energy consumed for RAM : 0.005074 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:26:25] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 21:26:25] Energy consumed for All CPU : 0.005697 kWh
# [codecarbon INFO @ 21:26:25] Energy consumed for all GPUs : 0.010792 kWh. Total GPU Power : 82.80077356556815 W
# [codecarbon INFO @ 21:26:25] 0.021563 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:26:41] Energy consumed for RAM : 0.005244 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:26:41] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:26:41] Energy consumed for All CPU : 0.005886 kWh
# [codecarbon INFO @ 21:26:41] Energy consumed for all GPUs : 0.011161 kWh. Total GPU Power : 81.83004816632638 W
# [codecarbon INFO @ 21:26:41] 0.022291 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:26:41] 0.020366 g.CO2eq/s mean an estimation of 642.2485945075468 kg.CO2eq/year
# [codecarbon INFO @ 21:26:57] Energy consumed for RAM : 0.005415 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:26:57] Delta energy consumed for CPU with constant : 0.000192 kWh, power : 42.5 W
# [codecarbon INFO @ 21:26:57] Energy consumed for All CPU : 0.006078 kWh
# [codecarbon INFO @ 21:26:57] Energy consumed for all GPUs : 0.011539 kWh. Total GPU Power : 83.0144904579518 W
# [codecarbon INFO @ 21:26:57] 0.023031 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:27:13] Energy consumed for RAM : 0.005584 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:27:13] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 21:27:13] Energy consumed for All CPU : 0.006269 kWh
# [codecarbon INFO @ 21:27:14] Energy consumed for all GPUs : 0.011909 kWh. Total GPU Power : 82.1511918904155 W
# [codecarbon INFO @ 21:27:14] 0.023762 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:27:30] Energy consumed for RAM : 0.005755 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:27:30] Delta energy consumed for CPU with constant : 0.000192 kWh, power : 42.5 W
# [codecarbon INFO @ 21:27:30] Energy consumed for All CPU : 0.006461 kWh
# [codecarbon INFO @ 21:27:30] Energy consumed for all GPUs : 0.012283 kWh. Total GPU Power : 82.34852308906594 W
# [codecarbon INFO @ 21:27:30] 0.024499 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:27:46] Energy consumed for RAM : 0.005925 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:27:46] Delta energy consumed for CPU with constant : 0.000192 kWh, power : 42.5 W
# [codecarbon INFO @ 21:27:46] Energy consumed for All CPU : 0.006652 kWh
# [codecarbon INFO @ 21:27:46] Energy consumed for all GPUs : 0.012655 kWh. Total GPU Power : 81.82639895611453 W
# [codecarbon INFO @ 21:27:46] 0.025233 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:28:02] Energy consumed for RAM : 0.006094 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:28:03] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 21:28:03] Energy consumed for All CPU : 0.006844 kWh
# [codecarbon INFO @ 21:28:03] Energy consumed for all GPUs : 0.013027 kWh. Total GPU Power : 82.59258250737743 W
# [codecarbon INFO @ 21:28:03] 0.025965 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:28:19] Energy consumed for RAM : 0.006263 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:28:19] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:28:19] Energy consumed for All CPU : 0.007033 kWh
# [codecarbon INFO @ 21:28:19] Energy consumed for all GPUs : 0.013397 kWh. Total GPU Power : 81.95449216748185 W
# [codecarbon INFO @ 21:28:19] 0.026693 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:28:35] Energy consumed for RAM : 0.006434 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:28:35] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 21:28:35] Energy consumed for All CPU : 0.007224 kWh
# [codecarbon INFO @ 21:28:35] Energy consumed for all GPUs : 0.013767 kWh. Total GPU Power : 81.89001757406146 W
# [codecarbon INFO @ 21:28:35] 0.027426 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:28:51] Energy consumed for RAM : 0.006603 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:28:51] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:28:51] Energy consumed for All CPU : 0.007415 kWh
# [codecarbon INFO @ 21:28:51] Energy consumed for all GPUs : 0.014140 kWh. Total GPU Power : 82.56419830260313 W
# [codecarbon INFO @ 21:28:51] 0.028158 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:28:51] 0.021151 g.CO2eq/s mean an estimation of 667.0244287445422 kg.CO2eq/year
# [codecarbon INFO @ 21:29:08] Energy consumed for RAM : 0.006773 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:29:08] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:29:08] Energy consumed for All CPU : 0.007605 kWh
# [codecarbon INFO @ 21:29:08] Energy consumed for all GPUs : 0.014510 kWh. Total GPU Power : 82.48606994981894 W
# [codecarbon INFO @ 21:29:08] 0.028888 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:29:24] Energy consumed for RAM : 0.006943 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:29:24] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 21:29:24] Energy consumed for All CPU : 0.007796 kWh
# [codecarbon INFO @ 21:29:24] Energy consumed for all GPUs : 0.014884 kWh. Total GPU Power : 82.78861365392557 W
# [codecarbon INFO @ 21:29:24] 0.029623 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:29:40] Energy consumed for RAM : 0.007112 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:29:40] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:29:40] Energy consumed for All CPU : 0.007986 kWh
# [codecarbon INFO @ 21:29:40] Energy consumed for all GPUs : 0.015255 kWh. Total GPU Power : 82.47166804494296 W
# [codecarbon INFO @ 21:29:40] 0.030353 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:29:56] Energy consumed for RAM : 0.007281 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:29:56] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 21:29:56] Energy consumed for All CPU : 0.008177 kWh
# [codecarbon INFO @ 21:29:57] Energy consumed for all GPUs : 0.015626 kWh. Total GPU Power : 82.003660963516 W
# [codecarbon INFO @ 21:29:57] 0.031084 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:30:13] Energy consumed for RAM : 0.007452 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:30:13] Delta energy consumed for CPU with constant : 0.000192 kWh, power : 42.5 W
# [codecarbon INFO @ 21:30:13] Energy consumed for All CPU : 0.008369 kWh
# [codecarbon INFO @ 21:30:13] Energy consumed for all GPUs : 0.015999 kWh. Total GPU Power : 82.41712748041411 W
# [codecarbon INFO @ 21:30:13] 0.031820 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:30:29] Energy consumed for RAM : 0.007621 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:30:29] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:30:29] Energy consumed for All CPU : 0.008559 kWh
# [codecarbon INFO @ 21:30:29] Energy consumed for all GPUs : 0.016368 kWh. Total GPU Power : 81.89867465058086 W
# [codecarbon INFO @ 21:30:29] 0.032547 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:30:45] Energy consumed for RAM : 0.007788 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:30:45] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:30:45] Energy consumed for All CPU : 0.008748 kWh
# [codecarbon INFO @ 21:30:45] Energy consumed for all GPUs : 0.016743 kWh. Total GPU Power : 83.75010737721003 W
# [codecarbon INFO @ 21:30:45] 0.033280 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:31:01] Energy consumed for RAM : 0.007957 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:31:01] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:31:01] Energy consumed for All CPU : 0.008937 kWh
# [codecarbon INFO @ 21:31:01] Energy consumed for all GPUs : 0.017127 kWh. Total GPU Power : 85.60440559482176 W
# [codecarbon INFO @ 21:31:01] 0.034020 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:31:01] 0.021234 g.CO2eq/s mean an estimation of 669.6309320897448 kg.CO2eq/year
# [codecarbon INFO @ 21:31:18] Energy consumed for RAM : 0.008127 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:31:18] Delta energy consumed for CPU with constant : 0.000192 kWh, power : 42.5 W
# [codecarbon INFO @ 21:31:18] Energy consumed for All CPU : 0.009129 kWh
# [codecarbon INFO @ 21:31:18] Energy consumed for all GPUs : 0.017499 kWh. Total GPU Power : 81.7301490185933 W
# [codecarbon INFO @ 21:31:18] 0.034754 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:31:34] Energy consumed for RAM : 0.008295 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:31:34] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:31:34] Energy consumed for All CPU : 0.009317 kWh
# [codecarbon INFO @ 21:31:34] Energy consumed for all GPUs : 0.017875 kWh. Total GPU Power : 84.0838938787091 W
# [codecarbon INFO @ 21:31:34] 0.035487 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:31:50] Energy consumed for RAM : 0.008459 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:31:50] Delta energy consumed for CPU with constant : 0.000185 kWh, power : 42.5 W
# [codecarbon INFO @ 21:31:50] Energy consumed for All CPU : 0.009502 kWh
# [codecarbon INFO @ 21:31:50] Energy consumed for all GPUs : 0.018247 kWh. Total GPU Power : 84.94585770007173 W
# [codecarbon INFO @ 21:31:50] 0.036209 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:32:05] Energy consumed for RAM : 0.008619 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:32:05] Delta energy consumed for CPU with constant : 0.000179 kWh, power : 42.5 W
# [codecarbon INFO @ 21:32:05] Energy consumed for All CPU : 0.009681 kWh
# [codecarbon INFO @ 21:32:05] Energy consumed for all GPUs : 0.018540 kWh. Total GPU Power : 69.24937661523062 W
# [codecarbon INFO @ 21:32:05] 0.036839 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:32:20] Energy consumed for RAM : 0.008779 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:32:20] Delta energy consumed for CPU with constant : 0.000180 kWh, power : 42.5 W
# [codecarbon INFO @ 21:32:20] Energy consumed for All CPU : 0.009861 kWh
# [codecarbon INFO @ 21:32:20] Energy consumed for all GPUs : 0.018771 kWh. Total GPU Power : 54.23257946557866 W
# [codecarbon INFO @ 21:32:20] 0.037412 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:32:36] Energy consumed for RAM : 0.008942 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:32:36] Delta energy consumed for CPU with constant : 0.000184 kWh, power : 42.5 W
# [codecarbon INFO @ 21:32:36] Energy consumed for All CPU : 0.010045 kWh
# [codecarbon INFO @ 21:32:36] Energy consumed for all GPUs : 0.019108 kWh. Total GPU Power : 77.64225614738653 W
# [codecarbon INFO @ 21:32:36] 0.038096 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:32:52] Energy consumed for RAM : 0.009111 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:32:52] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:32:52] Energy consumed for All CPU : 0.010235 kWh
# [codecarbon INFO @ 21:32:52] Energy consumed for all GPUs : 0.019472 kWh. Total GPU Power : 80.87577864701097 W
# [codecarbon INFO @ 21:32:52] 0.038817 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:33:08] Energy consumed for RAM : 0.009279 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:33:08] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:33:08] Energy consumed for All CPU : 0.010424 kWh
# [codecarbon INFO @ 21:33:08] Energy consumed for all GPUs : 0.019845 kWh. Total GPU Power : 83.4233688829946 W
# [codecarbon INFO @ 21:33:08] 0.039548 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:33:08] 0.020498 g.CO2eq/s mean an estimation of 646.4131765285565 kg.CO2eq/year
# [codecarbon INFO @ 21:33:24] Energy consumed for RAM : 0.009448 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:33:25] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:33:25] Energy consumed for All CPU : 0.010614 kWh
# [codecarbon INFO @ 21:33:25] Energy consumed for all GPUs : 0.020213 kWh. Total GPU Power : 81.60149609335238 W
# [codecarbon INFO @ 21:33:25] 0.040275 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:33:41] Energy consumed for RAM : 0.009617 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:33:41] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:33:41] Energy consumed for All CPU : 0.010804 kWh
# [codecarbon INFO @ 21:33:41] Energy consumed for all GPUs : 0.020586 kWh. Total GPU Power : 83.10128956615158 W
# [codecarbon INFO @ 21:33:41] 0.041007 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:33:57] Energy consumed for RAM : 0.009785 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:33:57] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 21:33:57] Energy consumed for All CPU : 0.010994 kWh
# [codecarbon INFO @ 21:33:57] Energy consumed for all GPUs : 0.020960 kWh. Total GPU Power : 83.02378693630185 W
# [codecarbon INFO @ 21:33:57] 0.041739 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:34:13] Energy consumed for RAM : 0.009954 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:34:13] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 21:34:13] Energy consumed for All CPU : 0.011185 kWh
# [codecarbon INFO @ 21:34:13] Energy consumed for all GPUs : 0.021330 kWh. Total GPU Power : 81.94694809737402 W
# [codecarbon INFO @ 21:34:13] 0.042469 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:34:29] Energy consumed for RAM : 0.010123 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:34:29] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:34:29] Energy consumed for All CPU : 0.011374 kWh
# [codecarbon INFO @ 21:34:29] Energy consumed for all GPUs : 0.021702 kWh. Total GPU Power : 82.98103240800533 W
# [codecarbon INFO @ 21:34:30] 0.043199 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:34:45] Energy consumed for RAM : 0.010290 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:34:46] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:34:46] Energy consumed for All CPU : 0.011563 kWh
# [codecarbon INFO @ 21:34:46] Energy consumed for all GPUs : 0.022074 kWh. Total GPU Power : 83.19788001501206 W
# [codecarbon INFO @ 21:34:46] 0.043927 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:35:02] Energy consumed for RAM : 0.010458 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:35:02] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:35:02] Energy consumed for All CPU : 0.011751 kWh
# [codecarbon INFO @ 21:35:02] Energy consumed for all GPUs : 0.022447 kWh. Total GPU Power : 83.96370302029356 W
# [codecarbon INFO @ 21:35:02] 0.044656 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:35:18] Energy consumed for RAM : 0.010626 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:35:18] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:35:18] Energy consumed for All CPU : 0.011940 kWh
# [codecarbon INFO @ 21:35:18] Energy consumed for all GPUs : 0.022825 kWh. Total GPU Power : 84.76780017818491 W
# [codecarbon INFO @ 21:35:18] 0.045392 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:35:18] 0.021251 g.CO2eq/s mean an estimation of 670.1867784545276 kg.CO2eq/year
# [codecarbon INFO @ 21:35:34] Energy consumed for RAM : 0.010793 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:35:34] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:35:34] Energy consumed for All CPU : 0.012128 kWh
# [codecarbon INFO @ 21:35:34] Energy consumed for all GPUs : 0.023195 kWh. Total GPU Power : 83.18783762140316 W
# [codecarbon INFO @ 21:35:34] 0.046116 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:35:50] Energy consumed for RAM : 0.010960 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:35:50] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:35:50] Energy consumed for All CPU : 0.012315 kWh
# [codecarbon INFO @ 21:35:50] Energy consumed for all GPUs : 0.023568 kWh. Total GPU Power : 83.65983270827233 W
# [codecarbon INFO @ 21:35:50] 0.046843 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:36:06] Energy consumed for RAM : 0.011127 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:36:06] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:36:06] Energy consumed for All CPU : 0.012503 kWh
# [codecarbon INFO @ 21:36:06] Energy consumed for all GPUs : 0.023938 kWh. Total GPU Power : 83.11412087956869 W
# [codecarbon INFO @ 21:36:06] 0.047568 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:36:22] Energy consumed for RAM : 0.011294 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:36:22] Delta energy consumed for CPU with constant : 0.000187 kWh, power : 42.5 W
# [codecarbon INFO @ 21:36:22] Energy consumed for All CPU : 0.012691 kWh
# [codecarbon INFO @ 21:36:22] Energy consumed for all GPUs : 0.024305 kWh. Total GPU Power : 82.87631939822877 W
# [codecarbon INFO @ 21:36:22] 0.048289 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:36:38] Energy consumed for RAM : 0.011460 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:36:38] Delta energy consumed for CPU with constant : 0.000187 kWh, power : 42.5 W
# [codecarbon INFO @ 21:36:38] Energy consumed for All CPU : 0.012878 kWh
# [codecarbon INFO @ 21:36:38] Energy consumed for all GPUs : 0.024668 kWh. Total GPU Power : 81.73345712201532 W
# [codecarbon INFO @ 21:36:38] 0.049005 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:36:54] Energy consumed for RAM : 0.011627 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:36:54] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:36:54] Energy consumed for All CPU : 0.013066 kWh
# [codecarbon INFO @ 21:36:54] Energy consumed for all GPUs : 0.025027 kWh. Total GPU Power : 80.73921654941105 W
# [codecarbon INFO @ 21:36:54] 0.049720 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:37:10] Energy consumed for RAM : 0.011795 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:37:10] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:37:10] Energy consumed for All CPU : 0.013255 kWh
# [codecarbon INFO @ 21:37:10] Energy consumed for all GPUs : 0.025389 kWh. Total GPU Power : 81.04181783377865 W
# [codecarbon INFO @ 21:37:10] 0.050438 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:37:26] Energy consumed for RAM : 0.011962 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:37:26] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:37:26] Energy consumed for All CPU : 0.013443 kWh
# [codecarbon INFO @ 21:37:26] Energy consumed for all GPUs : 0.025754 kWh. Total GPU Power : 81.83372302342198 W
# [codecarbon INFO @ 21:37:26] 0.051160 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:37:26] 0.021124 g.CO2eq/s mean an estimation of 666.15938629078 kg.CO2eq/year
# [codecarbon INFO @ 21:37:42] Energy consumed for RAM : 0.012130 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:37:42] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:37:42] Energy consumed for All CPU : 0.013632 kWh
# [codecarbon INFO @ 21:37:43] Energy consumed for all GPUs : 0.026124 kWh. Total GPU Power : 82.76554799484956 W
# [codecarbon INFO @ 21:37:43] 0.051885 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:37:58] Energy consumed for RAM : 0.012297 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:37:58] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:37:59] Energy consumed for All CPU : 0.013820 kWh
# [codecarbon INFO @ 21:37:59] Energy consumed for all GPUs : 0.026498 kWh. Total GPU Power : 84.09498848502832 W
# [codecarbon INFO @ 21:37:59] 0.052615 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:38:15] Energy consumed for RAM : 0.012464 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:38:15] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:38:15] Energy consumed for All CPU : 0.014008 kWh
# [codecarbon INFO @ 21:38:15] Energy consumed for all GPUs : 0.026871 kWh. Total GPU Power : 83.63616700282809 W
# [codecarbon INFO @ 21:38:15] 0.053343 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:38:31] Energy consumed for RAM : 0.012631 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:38:31] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:38:31] Energy consumed for All CPU : 0.014196 kWh
# [codecarbon INFO @ 21:38:31] Energy consumed for all GPUs : 0.027242 kWh. Total GPU Power : 83.54449231506709 W
# [codecarbon INFO @ 21:38:31] 0.054068 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:38:46] Energy consumed for RAM : 0.012789 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:38:46] Delta energy consumed for CPU with constant : 0.000178 kWh, power : 42.5 W
# [codecarbon INFO @ 21:38:46] Energy consumed for All CPU : 0.014374 kWh
# [codecarbon INFO @ 21:38:46] Energy consumed for all GPUs : 0.027611 kWh. Total GPU Power : 88.19299501113728 W
# [codecarbon INFO @ 21:38:46] 0.054774 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:39:01] Energy consumed for RAM : 0.012953 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:39:01] Delta energy consumed for CPU with constant : 0.000184 kWh, power : 42.5 W
# [codecarbon INFO @ 21:39:01] Energy consumed for All CPU : 0.014558 kWh
# [codecarbon INFO @ 21:39:01] Energy consumed for all GPUs : 0.027861 kWh. Total GPU Power : 57.47754285841568 W
# [codecarbon INFO @ 21:39:01] 0.055372 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:39:16] Energy consumed for RAM : 0.013111 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:39:16] Delta energy consumed for CPU with constant : 0.000176 kWh, power : 42.5 W
# [codecarbon INFO @ 21:39:16] Energy consumed for All CPU : 0.014734 kWh
# [codecarbon INFO @ 21:39:16] Energy consumed for all GPUs : 0.028075 kWh. Total GPU Power : 51.674330865967086 W
# [codecarbon INFO @ 21:39:16] 0.055920 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:39:32] Energy consumed for RAM : 0.013275 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:39:32] Delta energy consumed for CPU with constant : 0.000184 kWh, power : 42.5 W
# [codecarbon INFO @ 21:39:32] Energy consumed for All CPU : 0.014918 kWh
# [codecarbon INFO @ 21:39:32] Energy consumed for all GPUs : 0.028401 kWh. Total GPU Power : 74.94688144796419 W
# [codecarbon INFO @ 21:39:32] 0.056594 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:39:32] 0.020352 g.CO2eq/s mean an estimation of 641.8245819460236 kg.CO2eq/year
# [codecarbon INFO @ 21:39:48] Energy consumed for RAM : 0.013443 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:39:48] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:39:48] Energy consumed for All CPU : 0.015107 kWh
# [codecarbon INFO @ 21:39:48] Energy consumed for all GPUs : 0.028772 kWh. Total GPU Power : 82.7018822712295 W
# [codecarbon INFO @ 21:39:48] 0.057322 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:40:04] Energy consumed for RAM : 0.013610 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:40:04] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:40:04] Energy consumed for All CPU : 0.015295 kWh
# [codecarbon INFO @ 21:40:04] Energy consumed for all GPUs : 0.029134 kWh. Total GPU Power : 81.50483017331679 W
# [codecarbon INFO @ 21:40:04] 0.058039 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:40:20] Energy consumed for RAM : 0.013778 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:40:20] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:40:20] Energy consumed for All CPU : 0.015484 kWh
# [codecarbon INFO @ 21:40:20] Energy consumed for all GPUs : 0.029502 kWh. Total GPU Power : 82.3712956655987 W
# [codecarbon INFO @ 21:40:21] 0.058765 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:40:36] Energy consumed for RAM : 0.013945 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:40:36] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:40:37] Energy consumed for All CPU : 0.015672 kWh
# [codecarbon INFO @ 21:40:37] Energy consumed for all GPUs : 0.029878 kWh. Total GPU Power : 84.22341407682114 W
# [codecarbon INFO @ 21:40:37] 0.059495 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:40:53] Energy consumed for RAM : 0.014113 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:40:53] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:40:53] Energy consumed for All CPU : 0.015861 kWh
# [codecarbon INFO @ 21:40:53] Energy consumed for all GPUs : 0.030246 kWh. Total GPU Power : 82.40278379791762 W
# [codecarbon INFO @ 21:40:53] 0.060220 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:41:09] Energy consumed for RAM : 0.014280 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:41:09] Delta energy consumed for CPU with constant : 0.000187 kWh, power : 42.5 W
# [codecarbon INFO @ 21:41:09] Energy consumed for All CPU : 0.016048 kWh
# [codecarbon INFO @ 21:41:09] Energy consumed for all GPUs : 0.030615 kWh. Total GPU Power : 83.41159663565263 W
# [codecarbon INFO @ 21:41:09] 0.060943 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:41:25] Energy consumed for RAM : 0.014447 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:41:25] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:41:25] Energy consumed for All CPU : 0.016237 kWh
# [codecarbon INFO @ 21:41:25] Energy consumed for all GPUs : 0.030982 kWh. Total GPU Power : 82.20099494743698 W
# [codecarbon INFO @ 21:41:25] 0.061667 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:41:41] Energy consumed for RAM : 0.014615 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:41:41] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:41:41] Energy consumed for All CPU : 0.016426 kWh
# [codecarbon INFO @ 21:41:41] Energy consumed for all GPUs : 0.031346 kWh. Total GPU Power : 81.26964003146175 W
# [codecarbon INFO @ 21:41:41] 0.062386 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:41:41] 0.021176 g.CO2eq/s mean an estimation of 667.8202518547168 kg.CO2eq/year
# [codecarbon INFO @ 21:41:57] Energy consumed for RAM : 0.014781 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:41:57] Delta energy consumed for CPU with constant : 0.000187 kWh, power : 42.5 W
# [codecarbon INFO @ 21:41:57] Energy consumed for All CPU : 0.016613 kWh
# [codecarbon INFO @ 21:41:57] Energy consumed for all GPUs : 0.031709 kWh. Total GPU Power : 81.84489430382219 W
# [codecarbon INFO @ 21:41:57] 0.063104 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:42:13] Energy consumed for RAM : 0.014948 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:42:13] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:42:13] Energy consumed for All CPU : 0.016801 kWh
# [codecarbon INFO @ 21:42:13] Energy consumed for all GPUs : 0.032070 kWh. Total GPU Power : 80.7258953040355 W
# [codecarbon INFO @ 21:42:13] 0.063819 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:42:29] Energy consumed for RAM : 0.015117 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:42:29] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:42:29] Energy consumed for All CPU : 0.016990 kWh
# [codecarbon INFO @ 21:42:29] Energy consumed for all GPUs : 0.032433 kWh. Total GPU Power : 81.04545822939001 W
# [codecarbon INFO @ 21:42:29] 0.064540 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:42:45] Energy consumed for RAM : 0.015284 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:42:45] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:42:45] Energy consumed for All CPU : 0.017179 kWh
# [codecarbon INFO @ 21:42:45] Energy consumed for all GPUs : 0.032801 kWh. Total GPU Power : 82.65080449873695 W
# [codecarbon INFO @ 21:42:45] 0.065264 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:43:01] Energy consumed for RAM : 0.015451 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:43:01] Delta energy consumed for CPU with constant : 0.000187 kWh, power : 42.5 W
# [codecarbon INFO @ 21:43:01] Energy consumed for All CPU : 0.017366 kWh
# [codecarbon INFO @ 21:43:01] Energy consumed for all GPUs : 0.033164 kWh. Total GPU Power : 81.85416917475351 W
# [codecarbon INFO @ 21:43:01] 0.065981 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:43:17] Energy consumed for RAM : 0.015618 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:43:17] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:43:17] Energy consumed for All CPU : 0.017554 kWh
# [codecarbon INFO @ 21:43:17] Energy consumed for all GPUs : 0.033527 kWh. Total GPU Power : 81.49090626818906 W
# [codecarbon INFO @ 21:43:17] 0.066698 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:43:33] Energy consumed for RAM : 0.015785 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:43:33] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:43:33] Energy consumed for All CPU : 0.017741 kWh
# [codecarbon INFO @ 21:43:33] Energy consumed for all GPUs : 0.033887 kWh. Total GPU Power : 80.77460015696377 W
# [codecarbon INFO @ 21:43:33] 0.067412 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:43:49] Energy consumed for RAM : 0.015952 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:43:49] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:43:49] Energy consumed for All CPU : 0.017930 kWh
# [codecarbon INFO @ 21:43:49] Energy consumed for all GPUs : 0.034249 kWh. Total GPU Power : 80.91834357172871 W
# [codecarbon INFO @ 21:43:49] 0.068132 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:43:49] 0.021038 g.CO2eq/s mean an estimation of 663.4476236501954 kg.CO2eq/year
# [codecarbon INFO @ 21:44:05] Energy consumed for RAM : 0.016120 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:44:05] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 21:44:05] Energy consumed for All CPU : 0.018119 kWh
# [codecarbon INFO @ 21:44:06] Energy consumed for all GPUs : 0.034618 kWh. Total GPU Power : 82.78368992233156 W
# [codecarbon INFO @ 21:44:06] 0.068858 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:44:21] Energy consumed for RAM : 0.016287 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:44:22] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:44:22] Energy consumed for All CPU : 0.018307 kWh
# [codecarbon INFO @ 21:44:22] Energy consumed for all GPUs : 0.034989 kWh. Total GPU Power : 83.21707389389057 W
# [codecarbon INFO @ 21:44:22] 0.069584 kWh of electricity used since the beginning.
# [codecarbon INFO @ 21:44:38] Energy consumed for RAM : 0.016455 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 21:44:38] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 21:44:38] Energy consumed for All CPU : 0.018496 kWh
# ...
# [codecarbon INFO @ 22:04:57] Energy consumed for All CPU : 0.032772 kWh
# [codecarbon INFO @ 22:04:57] Energy consumed for all GPUs : 0.062580 kWh. Total GPU Power : 81.23150576793356 W
# [codecarbon INFO @ 22:04:57] 0.124506 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:05:13] Energy consumed for RAM : 0.029322 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:05:13] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 22:05:13] Energy consumed for All CPU : 0.032962 kWh
# [codecarbon INFO @ 22:05:13] Energy consumed for all GPUs : 0.062950 kWh. Total GPU Power : 82.15780693644682 W
# [codecarbon INFO @ 22:05:13] 0.125234 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:05:13] 0.021124 g.CO2eq/s mean an estimation of 666.1629546420999 kg.CO2eq/year
# [codecarbon INFO @ 22:05:28] Energy consumed for RAM : 0.029478 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:05:28] Delta energy consumed for CPU with constant : 0.000175 kWh, power : 42.5 W
# [codecarbon INFO @ 22:05:28] Energy consumed for All CPU : 0.033136 kWh
# [codecarbon INFO @ 22:05:28] Energy consumed for all GPUs : 0.063298 kWh. Total GPU Power : 84.63849846543853 W
# [codecarbon INFO @ 22:05:28] 0.125913 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:05:44] Energy consumed for RAM : 0.029648 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:05:44] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 22:05:44] Energy consumed for All CPU : 0.033327 kWh
# [codecarbon INFO @ 22:05:44] Energy consumed for all GPUs : 0.063662 kWh. Total GPU Power : 80.76043605717108 W
# [codecarbon INFO @ 22:05:44] 0.126636 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:06:00] Energy consumed for RAM : 0.029816 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:06:00] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 22:06:01] Energy consumed for All CPU : 0.033517 kWh
# [codecarbon INFO @ 22:06:01] Energy consumed for all GPUs : 0.064034 kWh. Total GPU Power : 82.88357801001807 W
# [codecarbon INFO @ 22:06:01] 0.127367 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:06:17] Energy consumed for RAM : 0.029986 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:06:17] Delta energy consumed for CPU with constant : 0.000192 kWh, power : 42.5 W
# [codecarbon INFO @ 22:06:17] Energy consumed for All CPU : 0.033708 kWh
# [codecarbon INFO @ 22:06:17] Energy consumed for all GPUs : 0.064399 kWh. Total GPU Power : 80.20599780465037 W
# [codecarbon INFO @ 22:06:17] 0.128094 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:06:32] Energy consumed for RAM : 0.030149 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:06:32] Delta energy consumed for CPU with constant : 0.000183 kWh, power : 42.5 W
# [codecarbon INFO @ 22:06:32] Energy consumed for All CPU : 0.033891 kWh
# [codecarbon INFO @ 22:06:32] Energy consumed for all GPUs : 0.064720 kWh. Total GPU Power : 74.58010333630914 W
# [codecarbon INFO @ 22:06:32] 0.128760 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:06:47] Energy consumed for RAM : 0.030307 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:06:47] Delta energy consumed for CPU with constant : 0.000177 kWh, power : 42.5 W
# [codecarbon INFO @ 22:06:47] Energy consumed for All CPU : 0.034068 kWh
# [codecarbon INFO @ 22:06:47] Energy consumed for all GPUs : 0.064959 kWh. Total GPU Power : 57.524103017920154 W
# [codecarbon INFO @ 22:06:47] 0.129334 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:07:03] Energy consumed for RAM : 0.030475 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:07:03] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 22:07:03] Energy consumed for All CPU : 0.034257 kWh
# [codecarbon INFO @ 22:07:04] Energy consumed for all GPUs : 0.065256 kWh. Total GPU Power : 66.09898533578955 W
# [codecarbon INFO @ 22:07:04] 0.129988 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:07:20] Energy consumed for RAM : 0.030643 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:07:20] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 22:07:20] Energy consumed for All CPU : 0.034447 kWh
# [codecarbon INFO @ 22:07:20] Energy consumed for all GPUs : 0.065627 kWh. Total GPU Power : 82.48006264607875 W
# [codecarbon INFO @ 22:07:20] 0.130717 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:07:20] 0.020403 g.CO2eq/s mean an estimation of 643.4416530837318 kg.CO2eq/year
# [codecarbon INFO @ 22:07:36] Energy consumed for RAM : 0.030813 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:07:36] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 22:07:36] Energy consumed for All CPU : 0.034638 kWh
# [codecarbon INFO @ 22:07:36] Energy consumed for all GPUs : 0.065994 kWh. Total GPU Power : 81.1153968466095 W
# [codecarbon INFO @ 22:07:36] 0.131445 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:07:52] Energy consumed for RAM : 0.030983 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:07:52] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 22:07:52] Energy consumed for All CPU : 0.034830 kWh
# [codecarbon INFO @ 22:07:52] Energy consumed for all GPUs : 0.066358 kWh. Total GPU Power : 80.88254353004417 W
# [codecarbon INFO @ 22:07:52] 0.132171 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:08:09] Energy consumed for RAM : 0.031152 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:08:09] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 22:08:09] Energy consumed for All CPU : 0.035020 kWh
# [codecarbon INFO @ 22:08:09] Energy consumed for all GPUs : 0.066727 kWh. Total GPU Power : 81.64556995561564 W
# [codecarbon INFO @ 22:08:09] 0.132900 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:08:25] Energy consumed for RAM : 0.031321 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:08:25] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:08:25] Energy consumed for All CPU : 0.035210 kWh
# [codecarbon INFO @ 22:08:25] Energy consumed for all GPUs : 0.067092 kWh. Total GPU Power : 81.63425738754063 W
# [codecarbon INFO @ 22:08:25] 0.133623 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:08:41] Energy consumed for RAM : 0.031489 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:08:41] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:08:41] Energy consumed for All CPU : 0.035399 kWh
# [codecarbon INFO @ 22:08:41] Energy consumed for all GPUs : 0.067459 kWh. Total GPU Power : 81.3565678821262 W
# [codecarbon INFO @ 22:08:41] 0.134347 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:08:57] Energy consumed for RAM : 0.031658 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:08:57] Delta energy consumed for CPU with constant : 0.000191 kWh, power : 42.5 W
# [codecarbon INFO @ 22:08:57] Energy consumed for All CPU : 0.035590 kWh
# [codecarbon INFO @ 22:08:57] Energy consumed for all GPUs : 0.067826 kWh. Total GPU Power : 81.34947482426612 W
# [codecarbon INFO @ 22:08:57] 0.135074 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:09:13] Energy consumed for RAM : 0.031827 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:09:13] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 22:09:14] Energy consumed for All CPU : 0.035780 kWh
# [codecarbon INFO @ 22:09:14] Energy consumed for all GPUs : 0.068195 kWh. Total GPU Power : 81.84084798103089 W
# [codecarbon INFO @ 22:09:14] 0.135802 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:09:30] Energy consumed for RAM : 0.031996 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:09:30] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 22:09:30] Energy consumed for All CPU : 0.035970 kWh
# [codecarbon INFO @ 22:09:30] Energy consumed for all GPUs : 0.068564 kWh. Total GPU Power : 82.23990162201605 W
# [codecarbon INFO @ 22:09:30] 0.136530 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:09:30] 0.021041 g.CO2eq/s mean an estimation of 663.5582853119338 kg.CO2eq/year
# [codecarbon INFO @ 22:09:46] Energy consumed for RAM : 0.032165 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:09:46] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 22:09:46] Energy consumed for All CPU : 0.036161 kWh
# [codecarbon INFO @ 22:09:46] Energy consumed for all GPUs : 0.068934 kWh. Total GPU Power : 82.00533280866571 W
# [codecarbon INFO @ 22:09:46] 0.137259 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:10:02] Energy consumed for RAM : 0.032332 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:10:02] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 22:10:02] Energy consumed for All CPU : 0.036349 kWh
# [codecarbon INFO @ 22:10:02] Energy consumed for all GPUs : 0.069299 kWh. Total GPU Power : 82.16075773424359 W
# [codecarbon INFO @ 22:10:02] 0.137980 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:10:18] Energy consumed for RAM : 0.032500 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:10:18] Delta energy consumed for CPU with constant : 0.000190 kWh, power : 42.5 W
# [codecarbon INFO @ 22:10:18] Energy consumed for All CPU : 0.036539 kWh
# [codecarbon INFO @ 22:10:18] Energy consumed for all GPUs : 0.069664 kWh. Total GPU Power : 81.2306620069692 W
# [codecarbon INFO @ 22:10:18] 0.138703 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:10:34] Energy consumed for RAM : 0.032668 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:10:34] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:10:34] Energy consumed for All CPU : 0.036728 kWh
# [codecarbon INFO @ 22:10:35] Energy consumed for all GPUs : 0.070034 kWh. Total GPU Power : 82.27807106119711 W
# [codecarbon INFO @ 22:10:35] 0.139431 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:10:51] Energy consumed for RAM : 0.032837 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:10:51] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:10:51] Energy consumed for All CPU : 0.036918 kWh
# [codecarbon INFO @ 22:10:51] Energy consumed for all GPUs : 0.070399 kWh. Total GPU Power : 81.07783082094035 W
# [codecarbon INFO @ 22:10:51] 0.140153 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:11:07] Energy consumed for RAM : 0.033004 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:11:07] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:11:07] Energy consumed for All CPU : 0.037106 kWh
# [codecarbon INFO @ 22:11:07] Energy consumed for all GPUs : 0.070768 kWh. Total GPU Power : 83.02276051991691 W
# [codecarbon INFO @ 22:11:07] 0.140878 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:11:23] Energy consumed for RAM : 0.033172 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:11:23] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 22:11:23] Energy consumed for All CPU : 0.037294 kWh
# [codecarbon INFO @ 22:11:23] Energy consumed for all GPUs : 0.071141 kWh. Total GPU Power : 83.68974288543531 W
# [codecarbon INFO @ 22:11:23] 0.141607 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:11:39] Energy consumed for RAM : 0.033339 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:11:39] Delta energy consumed for CPU with constant : 0.000188 kWh, power : 42.5 W
# [codecarbon INFO @ 22:11:39] Energy consumed for All CPU : 0.037482 kWh
# [codecarbon INFO @ 22:11:39] Energy consumed for all GPUs : 0.071515 kWh. Total GPU Power : 83.90443499088721 W
# [codecarbon INFO @ 22:11:39] 0.142336 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:11:39] 0.021156 g.CO2eq/s mean an estimation of 667.1679625270896 kg.CO2eq/year
# [codecarbon INFO @ 22:11:55] Energy consumed for RAM : 0.033507 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:11:55] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:11:55] Energy consumed for All CPU : 0.037671 kWh
# [codecarbon INFO @ 22:11:55] Energy consumed for all GPUs : 0.071886 kWh. Total GPU Power : 82.57539780174376 W
# [codecarbon INFO @ 22:11:55] 0.143063 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:12:11] Energy consumed for RAM : 0.033675 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:12:11] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:12:11] Energy consumed for All CPU : 0.037860 kWh
# [codecarbon INFO @ 22:12:11] Energy consumed for all GPUs : 0.072246 kWh. Total GPU Power : 80.68561363346342 W
# [codecarbon INFO @ 22:12:11] 0.143781 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:12:27] Energy consumed for RAM : 0.033843 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:12:27] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:12:27] Energy consumed for All CPU : 0.038049 kWh
# [codecarbon INFO @ 22:12:27] Energy consumed for all GPUs : 0.072621 kWh. Total GPU Power : 83.89211800576187 W
# [codecarbon INFO @ 22:12:27] 0.144513 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:12:43] Energy consumed for RAM : 0.034011 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:12:43] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:12:44] Energy consumed for All CPU : 0.038237 kWh
# [codecarbon INFO @ 22:12:44] Energy consumed for all GPUs : 0.072983 kWh. Total GPU Power : 80.50365454691594 W
# [codecarbon INFO @ 22:12:44] 0.145231 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:13:00] Energy consumed for RAM : 0.034179 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:13:00] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:13:00] Energy consumed for All CPU : 0.038426 kWh
# [codecarbon INFO @ 22:13:00] Energy consumed for all GPUs : 0.073344 kWh. Total GPU Power : 80.68280514263323 W
# [codecarbon INFO @ 22:13:00] 0.145949 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:13:16] Energy consumed for RAM : 0.034346 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:13:16] Delta energy consumed for CPU with constant : 0.000189 kWh, power : 42.5 W
# [codecarbon INFO @ 22:13:16] Energy consumed for All CPU : 0.038615 kWh
# [codecarbon INFO @ 22:13:16] Energy consumed for all GPUs : 0.073712 kWh. Total GPU Power : 82.18184989641989 W
# [codecarbon INFO @ 22:13:16] 0.146674 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:13:31] Energy consumed for RAM : 0.034504 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:13:31] Delta energy consumed for CPU with constant : 0.000177 kWh, power : 42.5 W
# [codecarbon INFO @ 22:13:31] Energy consumed for All CPU : 0.038792 kWh
# [codecarbon INFO @ 22:13:31] Energy consumed for all GPUs : 0.073994 kWh. Total GPU Power : 67.77543473367572 W
# [codecarbon INFO @ 22:13:31] 0.147290 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:13:46] Energy consumed for RAM : 0.034662 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:13:46] Delta energy consumed for CPU with constant : 0.000176 kWh, power : 42.5 W
# [codecarbon INFO @ 22:13:46] Energy consumed for All CPU : 0.038968 kWh
# [codecarbon INFO @ 22:13:46] Energy consumed for all GPUs : 0.074220 kWh. Total GPU Power : 54.342521878604906 W
# [codecarbon INFO @ 22:13:46] 0.147850 kWh of electricity used since the beginning.
# [codecarbon INFO @ 22:13:46] 0.020471 g.CO2eq/s mean an estimation of 645.5760473786215 kg.CO2eq/year
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].

# %%
# Stop the emissions tracker after training is complete
emissions = tracker.stop()
print(f"Estimated CO2 emissions for training: {emissions} kg")
# Out:
# [codecarbon INFO @ 22:13:49] Energy consumed for RAM : 0.034693 kWh. RAM Power : 38.0 W
# [codecarbon INFO @ 22:13:49] Delta energy consumed for CPU with constant : 0.000036 kWh, power : 42.5 W
# [codecarbon INFO @ 22:13:49] Energy consumed for All CPU : 0.039004 kWh
# [codecarbon INFO @ 22:13:49] Energy consumed for all GPUs : 0.074262 kWh. Total GPU Power : 50.06983315793876 W
# [codecarbon INFO @ 22:13:49] 0.147959 kWh of electricity used since the beginning.
# Estimated CO2 emissions for training: 0.0696567052363746 kg

# %%
trainer.save_model()  # Save the final model

# %%
import pandas as pd

df = pd.DataFrame(trainer.state.log_history)
print(df[["epoch", "eval_loss", "loss"]].dropna())
# Out:
# Empty DataFrame
# Columns: [epoch, eval_loss, loss]
# Index: []

# %% [markdown]
# ## Evaluate

# %%
model.eval().to("cuda" if torch.cuda.is_available() else "cpu")

pred_strs = []
label_strs = []

forced_decoder_ids = processor.get_decoder_prompt_ids(language="es", task="transcribe")

for example in tqdm.tqdm(dataset["test"]):
    # Already pre-extracted features → convert to tensor and batch
    input_features = torch.tensor(example["input_features"]).unsqueeze(0).to(model.device)

    with torch.no_grad():
        predicted_ids = model.generate(
            input_features,
            forced_decoder_ids=forced_decoder_ids
        )

    pred_str = processor.tokenizer.batch_decode(predicted_ids, skip_special_tokens=True)[0]

    # Decode labels
    label_ids = example["labels"]
    label_ids = [token if token != -100 else processor.tokenizer.pad_token_id for token in label_ids]
    label_str = processor.tokenizer.decode(label_ids, skip_special_tokens=True)

    pred_strs.append(pred_str)
    label_strs.append(label_str)
# Out:
#   0%|          | 0/170 [00:00<?, ?it/s]The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# 100%|██████████| 170/170 [01:38<00:00,  1.72it/s]

# %%
wer = wer_metric.compute(predictions=pred_strs, references=label_strs)
print(f"Test WER: {wer:.4f}")
# Out:
# Test WER: 0.9514

# %%
def show_prediction_mismatches(pred_strs, label_strs, max_examples=10):
    mismatches = []

    for pred, ref in zip(pred_strs, label_strs):
        pred_clean = pred.strip()
        ref_clean = ref.strip()
        if pred_clean != ref_clean:
            mismatches.append((ref_clean, pred_clean))

    print(f"\nShowing {min(len(mismatches), max_examples)} mismatches out of {len(label_strs)} total samples:\n")

    for i, (ref, pred) in enumerate(mismatches[:max_examples]):
        print(f"[{i+1}]")
        print(f"REF : {ref}")
        print(f"PRED: {pred}")
        print("-" * 40)

    if len(mismatches) == 0:
        print("✅ No mismatches found! (unlikely if WER > 0)")

show_prediction_mismatches(pred_strs, label_strs, max_examples=10)
# Out:
# Showing 10 mismatches out of 170 total samples:
#
# [1]
# REF : tema nlhanie ktemakha
# PRED: "Llaniectemakha"
# ----------------------------------------
# [2]
# REF : lhta ntemak lhennenga
# PRED: la ntemak, la nlhennenga.
# ----------------------------------------
# [3]
# REF : lhta ngkeniem'ak ma'a temo lhta ngka
# PRED: al tangkeñama temen al tangka'a.
# ----------------------------------------
# [4]
# REF : nalhet aknem antemak ma'a
# PRED: Nalhetak nemantemak ma'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'
# ----------------------------------------
# [5]
# REF : taiepe' nalhepop nenlhengama
# PRED: tal vez malheopopop'o, nenglhengama hai'o.
# ----------------------------------------
# [6]
# REF : colonia menonita anio
# PRED: Colonia menonita, un caño,
# ----------------------------------------
# [7]
# REF : Toba niekhe Toba niekhe nhan hengka malha ketsek koka
# PRED: Toba niekhe nhanengka molhamok ketsek koka'a.
# ----------------------------------------
# [8]
# REF : mekka kpekhai'a kokam'a klhengama manie nak
# PRED: pekka pekhai'a ko'vam'a lhengamama manienek'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a
# ----------------------------------------
# [9]
# REF : malha eietkok koka sketlhelhmak lengua
# PRED: malheiettkok oka skelhelhma lengua'a?
# ----------------------------------------
# [10]
# REF : eietka, etava', ngkel-halhemmalhkehe'
# PRED: eietka, etava, ngkelhalhemmalhkehe,
# ----------------------------------------

# %% [markdown]
# First complete run:
#
# ```
# [1]
# REF : nempai'akha mamma
# PRED: nengpaiakha mamma'a
# ----------------------------------------
# [2]
# REF : mo'ok alhta ngke kvai'o nak
# PRED: もかしたんけ コアイオナ
# ----------------------------------------
# [3]
# REF : kanhan entengiai'anhan peia'
# PRED: kanhan nentengiai'a i'a nha peia'a
# ----------------------------------------
# [4]
# REF : sekla ktemo nak kelvesai'a konalhma ie
# PRED: Секла, тема, тема на кервеса, кунахма, ехе
# ----------------------------------------
# [5]
# REF : netamen kelpaqmetek amelhanhan ma'a
# PRED: "نتام" "كل" "بقمتek" "a mellamhan ma'a"
# ----------------------------------------
# [6]
# REF : akiamasma aktoma niekhe' ngkelvana koka'
# PRED: akiamasma'a tomaniek hengkelvana koka'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'
# ----------------------------------------
# [7]
# REF : ngvai'a lhta niekhe nemmaskema m'a nenekev'
# PRED: アルタニアクhene マスケマ ア ネネクト
# ----------------------------------------
# [8]
# REF : sekhek nak ma'a
# PRED: alha m'o sekhek nak ma'a
# ----------------------------------------
# [9]
# REF : selha apvaneiam kelha
# PRED: Tiemme, c'est l'aie à la vanneiam pqlha'aie
# ----------------------------------------
# [10]
# REF : iamalheng alhta ngkolhek akto
# PRED: namalhega lhta ngko lha ektok'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'
# ----------------------------------------
# ```
#
# Not much improvement during the second round:
#
# ```
# [1]
# REF : nempai'akha mamma
# PRED: Nempaiakha mamma'a
# ----------------------------------------
# [2]
# REF : mo'ok alhta ngke kvai'o nak
# PRED: no vocalta, no que cuaiona
# ----------------------------------------
# [3]
# REF : kanhan entengiai'anhan peia'
# PRED: ganhan en teniai anhapeia'a.
# ----------------------------------------
# [4]
# REF : sekla ktemo nak kelvesai'a konalhma ie
# PRED: se aclaro que no, que no se acuerves a connalma ieh
# ----------------------------------------
# [5]
# REF : netamen kelpaqmetek amelhanhan ma'a
# PRED: netamen kelpaqmetekamelha mehanma'a
# ----------------------------------------
# [6]
# REF : akiamasma aktoma niekhe' ngkelvana koka'
# PRED: aquí amasma tomaniek hengkelvana koka
# ----------------------------------------
# [7]
# REF : ngvai'a lhta niekhe nemmaskema m'a nenekev'
# PRED: y altañekha nemmaskema'a nenekem'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a
# ----------------------------------------
# [8]
# REF : sekhek nak ma'a
# PRED: alhama se quehek nak ma'a
# ----------------------------------------
# [9]
# REF : selha apvaneiam kelha
# PRED: tiempiempsela acuaneiamkela'a
# ----------------------------------------
# [10]
# REF : iamalheng alhta ngkolhek akto
# PRED: namalhegaltangko lhektong'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'o'
# ----------------------------------------
# ```

# %%
from huggingface_hub import login
# login() # We don't need to call login interactively if we pass the token
model.push_to_hub("sjhuskey/enenlhet-whisper-model", commit_message="Updated model with emissions", token=hf_token)
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...het-whisper-model/model.safetensors:   0%|          |  569kB /  967MB
# CommitInfo(commit_url='https://huggingface.co/sjhuskey/enenlhet-whisper-model/commit/7299fbcb7b1815dd0d41944cafcb5914d69c4c74', commit_message='Updated model with emissions', commit_description='', oid='7299fbcb7b1815dd0d41944cafcb5914d69c4c74', pr_url=None, repo_url=RepoUrl('https://huggingface.co/sjhuskey/enenlhet-whisper-model', endpoint='https://huggingface.co', repo_type='model', repo_id='sjhuskey/enenlhet-whisper-model'), pr_revision=None, pr_num=None)
